# %%
#Binry Braile
a=100000
b=110000
c=100100
d=100110
e=100010
f=110100
g=110110
h=110010
i='010100'
j='010110'
k=a + 1000
l=b + 1000
m=c + 1000
n=d + 1000
o=e + 1000
p=f + 1000
q=g + 1000
r=h + 1000
s='011100'
t='011110'
u=k + 1
v=l + 1
w='010111'
x=m + 1
y=n + 1
z=o + 1
upper='000000'

A = upper + str(a)
B = upper + str(b)
C = upper + str(c)
D = upper + str(d)
E = upper + str(e)
F = upper + str(f)
G = upper + str(g)
H = upper + str(h)
I = upper + str(i)
J = upper + str(j)
K = upper + str(k)
L = upper + str(l)
M = upper + str(m)
N = upper + str(n)
O = upper + str(o)
P = upper + str(p)
Q = upper + str(q)
R = upper + str(r)
S = upper + str(s)
T = upper + str(t)
U = upper + str(u)
V = upper + str(v)
W = upper + str(w)
X = upper + str(z)
Y = upper + str(y)
Z = upper + str(z)

# %%
#Binry Braile
a=100000
b=110000
c=100100
d=100110
e=100010
f=110100
g=110110
h=110010
i='010100'
j='010110'
k=a + 1000
l=b + 1000
m=c + 1000
n=d + 1000
o=e + 1000
p=f + 1000
q=g + 1000
r=h + 1000
s='011100'
t='011110'
u=k + 1
v=l + 1
w='010111'
x=m + 1
y=n + 1
z=o + 1
upper='000001'

A = upper + str(a)
B = upper + str(b)
C = upper + str(c)
D = upper + str(d)
E = upper + str(e)
F = upper + str(f)
G = upper + str(g)
H = upper + str(h)
I = upper + str(i)
J = upper + str(j)
K = upper + str(k)
L = upper + str(l)
M = upper + str(m)
N = upper + str(n)
O = upper + str(o)
P = upper + str(p)
Q = upper + str(q)
R = upper + str(r)
S = upper + str(s)
T = upper + str(t)
U = upper + str(u)
V = upper + str(v)
W = upper + str(w)
X = upper + str(z)
Y = upper + str(y)
Z = upper + str(z)

#Input 
start = input()

word = start.replace('solution.solution("', ''). replace('")','')

b = word.replace(' ', '000000')\
.replace('a', str(a))\
.replace('a', str(a))\
.replace('b', str(b))\
.replace('c', str(c))\
.replace('d', str(d))\
.replace('e', str(e))\
.replace('f', str(f))\
.replace('g', str(g))\
.replace('h', str(h))\
.replace('i', str(i))\
.replace('j', str(j))\
.replace('k', str(k))\
.replace('l', str(l))\
.replace('m', str(m))\
.replace('n', str(n))\
.replace('o', str(o))\
.replace('p', str(p))\
.replace('q', str(q))\
.replace('r', str(r))\
.replace('s', str(s))\
.replace('t', str(t))\
.replace('u', str(u))\
.replace('v', str(v))\
.replace('w', str(w))\
.replace('x', str(x))\
.replace('y', str(y))\
.replace('z', str(z))\
.replace('A', A)\
.replace('B', B)\
.replace('C', C)\
.replace('D', D)\
.replace('E', E)\
.replace('F', F)\
.replace('G', G)\
.replace('H', H)\
.replace('I', I)\
.replace('J', J)\
.replace('K', K)\
.replace('L', L)\
.replace('M', M)\
.replace('N', N)\
.replace('O', O)\
.replace('P', P)\
.replace('Q', Q)\
.replace('R', R)\
.replace('S', S)\
.replace('T', T)\
.replace('U', U)\
.replace('V', V)\
.replace('W', W)\
.replace('X', X)\
.replace('Y', T)\
.replace('Z', Z)\

print (b)
# Out:
# solution.solution("The quick brown fox jumps over the lazy dog")
# 

# %%
from solution import solution
def solution(word):
    #Binry Braile
    a=100000
    b=110000
    c=100100
    d=100110
    e=100010
    f=110100
    g=110110
    h=110010
    i='010100'
    j='010110'
    k=a + 1000
    l=b + 1000
    m=c + 1000
    n=d + 1000
    o=e + 1000
    p=f + 1000
    q=g + 1000
    r=h + 1000
    s='011100'
    t='011110'
    u=k + 1
    v=l + 1
    w='010111'
    x=m + 1
    y=n + 1
    z=o + 1
    upper='000001'
    
    A = upper + str(a)
    B = upper + str(b)
    C = upper + str(c)
    D = upper + str(d)
    E = upper + str(e)
    F = upper + str(f)
    G = upper + str(g)
    H = upper + str(h)
    I = upper + str(i)
    J = upper + str(j)
    K = upper + str(k)
    L = upper + str(l)
    M = upper + str(m)
    N = upper + str(n)
    O = upper + str(o)
    P = upper + str(p)
    Q = upper + str(q)
    R = upper + str(r)
    S = upper + str(s)
    T = upper + str(t)
    U = upper + str(u)
    V = upper + str(v)
    W = upper + str(w)
    X = upper + str(z)
    Y = upper + str(y)
    Z = upper + str(z)
    
    
    
    word = word.replace('Solution.solution("', ''). replace('")','')
    
    b = word.replace(' ', '000000')\
    .replace('a', str(a))\
    .replace('a', str(a))\
    .replace('b', str(b))\
    .replace('c', str(c))\
    .replace('d', str(d))\
    .replace('e', str(e))\
    .replace('f', str(f))\
    .replace('g', str(g))\
    .replace('h', str(h))\
    .replace('i', str(i))\
    .replace('j', str(j))\
    .replace('k', str(k))\
    .replace('l', str(l))\
    .replace('m', str(m))\
    .replace('n', str(n))\
    .replace('o', str(o))\
    .replace('p', str(p))\
    .replace('q', str(q))\
    .replace('r', str(r))\
    .replace('s', str(s))\
    .replace('t', str(t))\
    .replace('u', str(u))\
    .replace('v', str(v))\
    .replace('w', str(w))\
    .replace('x', str(x))\
    .replace('y', str(y))\
    .replace('z', str(z))\
    .replace('A', A)\
    .replace('B', B)\
    .replace('C', C)\
    .replace('D', D)\
    .replace('E', E)\
    .replace('F', F)\
    .replace('G', G)\
    .replace('H', H)\
    .replace('I', I)\
    .replace('J', J)\
    .replace('K', K)\
    .replace('L', L)\
    .replace('M', M)\
    .replace('N', N)\
    .replace('O', O)\
    .replace('P', P)\
    .replace('Q', Q)\
    .replace('R', R)\
    .replace('S', S)\
    .replace('T', T)\
    .replace('U', U)\
    .replace('V', V)\
    .replace('W', W)\
    .replace('X', X)\
    .replace('Y', T)\
    .replace('Z', Z)\
    
    print (b)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-e0fd3378cb29> in <module>
# ----> 1 from solution import solution
#       2 def solution(word):
#       3     #Binry Braile
#       4     a=100000
#       5     b=110000
#
# ModuleNotFoundError: No module named 'solution'

# %%
solution("code")
# Out:
# 100100101010100110100010
